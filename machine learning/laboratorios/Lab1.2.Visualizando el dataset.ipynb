# %% [markdown]
# Introducción a Machine Learning
# =============
#
# Laboratorio 1. Parte 2. Visualización de dataset de Digitos Manuscritos
# ------------------------
#
# El objetivo de esta parte es cargar y visualizar el dataset de [dígitos manuscritos](http://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_digits.html) disponible en Scikit-Learn. Esta es una pequeña porción del conocido dataset [MNIST](http://yann.lecun.com/exdb/mnist/).
# Cada imagen es de 8x8 pixeles, con 1797 muestras distribuidas entre todas las clases (digitos del 0 al 9).

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# Config the matlotlib backend as plotting inline in IPython
# %matplotlib inline

# %% [markdown]
# Cargamos el dataset

# %%
digits = datasets.load_digits()

X, y = digits.data, digits.target

print(X.shape)
print(y.shape)
# Out:
# (1797, 64)
# (1797,)

# %% [markdown]
# Visualizamos las primeras 9 imagenes de un dígito

# %%
digit = 9 # cambiar para visualizar otro digito

Xdig = X[y==digit,:]
np.random.shuffle(Xdig)

plt.figure(figsize=(9,9))
for i in range(1,10):
    plt.subplot(3,3,i)
    plt.axis('off')
    plt.imshow(Xdig[i-1,:].reshape((8,8)),cmap='gray')
plt.show()

# %% [markdown]
# ---
# Ejercicio
# -----
# Halle los siguientes datos del dataset
# * Numero de muestras por clase (digito)
# * Valor minimo, maximo, media y varianza entre valores de pixel del dataset

# %%
# Out:
# digito 0: 178
# digito 1: 182
# digito 2: 177
# digito 3: 183
# digito 4: 181
# digito 5: 182
# digito 6: 181
# digito 7: 179
# digito 8: 174
# digito 9: 180

# %%
# Out:
# Media: 4.88416457986
# STD:
#  6.01678754867
# Range:
#  16.0
